# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from ast import literal_eval
from datasets import load_dataset
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: literal_eval(x) if pd.notna(x) else x)

# %%
df_da_us=df[(df['job_title_short']=='Data Analyst') & (df['job_country']=='United States')]
df_da_us
# Out:
#        job_title_short  ...                                    job_type_skills
# 36        Data Analyst  ...                                                NaN
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 79        Data Analyst  ...  {'analyst_tools': ['sas', 'word', 'excel'], 'p...
# 93        Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# ...                ...  ...                                                ...
# 785603    Data Analyst  ...  {'analyst_tools': ['excel'], 'other': ['flow']...
# 785626    Data Analyst  ...                      {'sync': ['microsoft teams']}
# 785685    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785703    Data Analyst  ...                                                NaN
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# ...

# %%
df_location=df_da_us['job_location'].value_counts().head(10).to_frame()
sns.set_theme(style='ticks')
sns.barplot(data=df_location,y='job_location',x='count',legend=False,hue='count',palette='dark:b_r')
sns.despine()
plt.title('No of Data Analyst Jobs Per Location')
plt.xlabel('Count')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(12, 8))

dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'Degree Mentioned',
    'job_health_insurance': 'Health Insurance Provided'
}

for i, (column, title) in enumerate(dict_column.items()):
    counts = df_da_us[column].value_counts()

    ax[i].pie(
        counts,
        labels=['False','True'],
        startangle=90,
        autopct='%1.1f%%'
    )
    
    ax[i].set_title(title)

plt.tight_layout()
plt.show()

# %%
df_companies=df_da_us['company_name'].value_counts().head(10).to_frame()
sns.set_theme(style='ticks')
sns.barplot(data=df_companies,x='count',y='company_name',hue='count',palette='dark:b_r',legend=False)
plt.tight_layout()
plt.title('Which Companies have Most Number of Data Analyst Job Postings?')
plt.xlabel('Job Count')
plt.ylabel('')
plt.show()
sns.despine()
